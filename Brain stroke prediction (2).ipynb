# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('C:/Users/Me/Desktop/JAYMESH/Brain Stroke/Brain stroke prediction data.csv')

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
df.shape
# Out:
# (4981, 11)

# %%
## To get how many different types of data types are present in dataset 
print("Unique Data type :",len(set(df.dtypes)))
print("Different types of datatypes in dataset are",set(df.dtypes))
# Out:
# Unique Data type : 3
# Different types of datatypes in dataset are {dtype('int64'), dtype('O'), dtype('float64')}

# %%
df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  4981.000000   4981.000000    4981.000000        4981.000000
# mean     43.419859      0.096165       0.055210         105.943562
# std      22.662755      0.294848       0.228412          45.075373
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.230000
# 50%      45.000000      0.000000       0.000000          91.850000
# 75%      61.000000      0.000000       0.000000         113.860000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4981.000000  4981.000000
# mean     28.498173     0.049789
# std       6.790464     0.217531
# min      14.000000     0.000000
# 25%      23.700000     0.000000
# 50%      28.100000     0.000000
# 75%      32.600000     0.000000
# max      48.900000     1.000000

# %%
df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df=df.dropna()
df.shape
# Out:
# (4981, 11)

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (4981, 11)

# %%
num_type = list(df.select_dtypes(include=['int64','float64']).columns)
print("Numbers of numeric type columns in data are" ,len(num_type))
print("Numeric type columns are " ,num_type)
# Out:
# Numbers of numeric type columns in data are 6
# Numeric type columns are  ['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi', 'stroke']

# %%
float_col = df.select_dtypes(include=['float64'])
for col in float_col.columns.values:
    df[col] = df[col].astype('int64')

# %%
df.head()
# Out:
#    gender  age  hypertension  heart_disease ever_married      work_type  \
# 0    Male   67             0              1          Yes        Private
# 1    Male   80             0              1          Yes        Private
# 2  Female   49             0              0          Yes        Private
# 3  Female   79             1              0          Yes  Self-employed
# 4    Male   81             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level  bmi   smoking_status  stroke
# 0          Urban                228   36  formerly smoked       1
# 1          Rural                105   32     never smoked       1
# 2          Urban                171   34           smokes       1
# 3          Rural                174   24     never smoked       1
# 4          Urban                186   29  formerly smoked       1

# %%
df.nunique()
# Out:
# gender                 2
# age                   83
# hypertension           2
# heart_disease          2
# ever_married           2
# work_type              4
# Residence_type         2
# avg_glucose_level    207
# bmi                   35
# smoking_status         4
# stroke                 2
# dtype: int64

# %%
df_ = df.drop(['age','avg_glucose_level','bmi'],axis=1)
for i in df_ .columns:
    print(df_[i].nunique())
# Out:
# 2
# 2
# 2
# 2
# 4
# 2
# 4
# 2

# %%
for i in df_ .columns:
    print(df_[i].value_counts())
# Out:
# Female    2907
# Male      2074
# Name: gender, dtype: int64
# 0    4502
# 1     479
# Name: hypertension, dtype: int64
# 0    4706
# 1     275
# Name: heart_disease, dtype: int64
# Yes    3280
# No     1701
# Name: ever_married, dtype: int64
# Private          2860
# Self-employed     804
# children          673
# Govt_job          644
# Name: work_type, dtype: int64
# Urban    2532
# Rural    2449
# Name: Residence_type, dtype: int64
# never smoked       1838
# Unknown            1500
# formerly smoked     867
# smokes              776
# Name: smoking_status, dtype: int64
# 0    4733
# 1     248
# Name: stroke, dtype: int64

# %%
for i in df_ .columns:
    plt.figure(figsize=(7,3))
    sns.countplot(df_ [i],data=df_ )

# %%
Smoke=df.groupby(['smoking_status'])['stroke'].sum()
Smoke.plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='stroke'>

# %%
#Conerting categorical variables to numerical
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['gender']=encoder.fit_transform(df['gender'])
df['Residence_type']=encoder.fit_transform(df['Residence_type'])
df['work_type']=encoder.fit_transform(df['work_type'])
df['smoking_status']=encoder.fit_transform(df['smoking_status'])
df['ever_married']=encoder.fit_transform(df['ever_married'])

# %%
df.head()
# Out:
#    gender  age  hypertension  heart_disease  ever_married  work_type  \
# 0       1   67             0              1             1          1
# 1       1   80             0              1             1          1
# 2       0   49             0              0             1          1
# 3       0   79             1              0             1          2
# 4       1   81             0              0             1          1
#
#    Residence_type  avg_glucose_level  bmi  smoking_status  stroke
# 0               1                228   36               1       1
# 1               0                105   32               2       1
# 2               1                171   34               3       1
# 3               0                174   24               2       1
# 4               1                186   29               1       1

# %%
## To visualize numeric type column boxplot is best way
num_features=['age', 'bmi']

n = 1
plt.figure(figsize=(20,15))

for column in num_features:
    plt.subplot(4,4,n)
    n = n+1
    sns.boxplot(df[column])
    plt.tight_layout()

# %% [markdown]
# # Multicollinearity

# %%
df.corr()
# Out:
#                      gender       age  hypertension  heart_disease  \
# gender             1.000000 -0.026634      0.021485       0.086476
# age               -0.026634  1.000000      0.278022       0.264725
# hypertension       0.021485  0.278022      1.000000       0.111974
# heart_disease      0.086476  0.264725      0.111974       1.000000
# ever_married      -0.028971  0.677196      0.164534       0.114765
# work_type          0.065784 -0.416531     -0.061618      -0.036943
# Residence_type    -0.004301  0.017148     -0.004755       0.002125
# avg_glucose_level  0.055730  0.236595      0.170095       0.166793
# bmi               -0.012091  0.374083      0.159291       0.061272
# smoking_status    -0.062666  0.266016      0.110045       0.048093
# stroke             0.008870  0.246349      0.131965       0.134610
#
#                    ever_married  work_type  Residence_type  avg_glucose_level  \
# gender                -0.028971   0.065784       -0.004301           0.055730
# ...

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, ax=ax);

# %%
X=df.drop(['stroke'],axis=1)
Y=df['stroke']

# %% [markdown]
# # TRAINING & TESTING

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=0,test_size=0.2)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (3984, 10)
# (3984,)
# (997, 10)
# (997,)

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,y_pred)
cm
# Out:
# array([[947,   0],
#        [ 50,   0]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
Accuracy = accuracy_score(y_pred , Y_test)
print('Accuracy of the logistic reg model is',Accuracy)
# Out:
# Accuracy of the logistic reg model is 0.9478435305917753

# %% [markdown]
# # DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier(criterion="entropy")
dtc.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dtc_pred=dtc.predict(X_test)
pd.DataFrame(dtc_pred)
# Out:
#      0
# 0    0
# 1    1
# 2    0
# 3    0
# 4    0
# ..  ..
# 992  0
# 993  0
# 994  0
# 995  0
# 996  0
#
# [997 rows x 1 columns]

# %%
cm=confusion_matrix(Y_test,dtc_pred)
cm
# Out:
# array([[898,  49],
#        [ 43,   7]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
Accuracy = accuracy_score(dtc_pred , Y_test)
print('Accuracy of the dtc model is',Accuracy)
# Out:
# Accuracy of the dtc model is 0.9077231695085256

# %%
from six import StringIO 
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

dot_data = StringIO()
export_graphviz(dtc, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# # Naive Bayes classifier

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, Y_train)
y_pred = gnb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
Accuracy = accuracy_score(y_pred , Y_test)
print('Accuracy of the Naive Bayes classifier model is',Accuracy)
# Out:
# Accuracy of the Naive Bayes classifier model is 0.872617853560682

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
# Here we import cofusion_matrix
from sklearn.metrics import confusion_matrix

# %%
acc=[]
k=[]
error=[]
for i in range(1,10):
    k.append(i)
    model=KNeighborsClassifier(n_neighbors=i)
    model.fit(X_train,Y_train)
    y_pred=model.predict(X_test)
    tab_1=confusion_matrix(y_pred,Y_test)
    acc.append(tab_1.diagonal().sum()/tab_1.sum())
    error.append(1-tab_1.diagonal().sum()/tab_1.sum())

# %%
knn = pd.DataFrame({"k":k,"Accuracy":acc,'Error':error})
knn
# Out:
#    k  Accuracy     Error
# 0  1  0.913741  0.086259
# 1  2  0.942828  0.057172
# 2  3  0.931795  0.068205
# 3  4  0.944835  0.055165
# 4  5  0.939819  0.060181
# 5  6  0.947844  0.052156
# 6  7  0.946841  0.053159
# 7  8  0.947844  0.052156
# 8  9  0.945838  0.054162

# %%
plt.figure(figsize=(8,8))
plt.plot(k,error,color="b",marker="*")
plt.xlabel('k',size =15)
plt.ylabel('error',size =15)
# Out:
# Text(0, 0.5, 'error')

# %%
model=KNeighborsClassifier(6)
model.fit(X_train,Y_train)
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
Accuracy = accuracy_score(y_pred , Y_test)
print('Accuracy of the  KNN model is',Accuracy)
# Out:
# Accuracy of the  KNN model is 0.9478435305917753

# %%
print('Accuracy of the logistic reg model is 0.9107321965897693')
print('Accuracy of the dtc model is 0.9147442326980942')
print('Accuracy of the Naive Bayes classifier model is 0.872617853560682')
print('Accuracy of the  KNN model is 0.9478435305917753')
# Out:
# Accuracy of the logistic reg model is 0.9107321965897693
# Accuracy of the dtc model is 0.9147442326980942
# Accuracy of the Naive Bayes classifier model is 0.872617853560682
# Accuracy of the  KNN model is 0.9478435305917753

# %% [markdown]
# # KNN model has the best accuracy which is 94 % so we choose KNN model
